# %%
for i in range(11):
    pass

# %%
for a in range(1,3):
    for b in range(1,13):
        print(a, 'x', b, '=', a*b)
# Out:
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5
# 1 x 6 = 6
# 1 x 7 = 7
# 1 x 8 = 8
# 1 x 9 = 9
# 1 x 10 = 10
# 1 x 11 = 11
# 1 x 12 = 12
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20
# 2 x 11 = 22
# 2 x 12 = 24

# %%
i = 5
while i < 5:
    print(i)
    i += 1
else:
    print('else:', i)
# Out:
# else: 5

# %%
i = 2
while i < 5:
    print(i)
    i += 1
else:
    print('else: ',i)
# Out:
# 2
# 3
# 4
# else:  5
