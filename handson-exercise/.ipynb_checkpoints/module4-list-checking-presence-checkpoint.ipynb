# %%
for char in 'Happy Message':
    print(char)
# Out:
# H
# a
# p
# p
# y
#
# M
# e
# s
# s
# a
# g
# e

# %%
invited_guests = ['Chandra', 'Ezhil', 'Akshayaa', 'Yazhnilaa', 'TKC', 'ECAY']
name = input('What is your name? ')
if name in invited_guests:
    print('You are invited!')
else:
    print('You are not invited')
# Out:
# What is your name?  Ezhil
# You are invited!

# %%
invited_guests = ['Chandra', 'Ezhil', 'Akshayaa', 'Yazhnilaa', 'TKC', 'ECAY']
name = input('What is your name? ')
if name not in invited_guests:
    print('Am sorry. You are not invited')
else:
    print('Welcome!')
# Out:
# What is your name?  Ezhil
# Welcome!
