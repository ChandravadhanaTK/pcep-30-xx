# %%
height_cm = input('Height converter: Enter your height in cm: ')
print('Your height in feet is: ', height_cm/30.48)
# Out:
# Height converter: Enter your height in cm:  156
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 height_cm = input('Height converter: Enter your height in cm: ')
# ----> 2 print('Your height in feet is: ', height_cm/30.48)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'float'

# %%
average_rating = input('Please provide your avg rating: ')
print(average_rating * 3)
# Out:
# Please provide your avg rating:  5.0
# 5.05.05.0

# %%
1 // 2 * 3
# Out:
# 0

# %%
number = int(input('Please provide a number: '))
print(number)
# Out:
# Please provide a number:  boom
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 number = int(input('Please provide a number: '))
#       2 print(number)
#
# ValueError: invalid literal for int() with base 10: 'boom'

# %%
1/1
# Out:
# 1.0

# %%
first_name = 'John'
print( sep=' - ', 'Your first name is', first_name, 'Welcome!')
# Out:
#   Cell In[17], line 2
#     print( sep=' - ', 'Your first name is', first_name, 'Welcome!')
#                                                                   ^
# SyntaxError: positional argument follows keyword argument

# %%
first_name = 'John'
print('Your first name is', first_name, 'Welcome!', sep=' - ')
# Out:
# Your first name is - John - Welcome!

# %%
x = 0
y = 1
a = x ^ y
b = x | y
c = x & y
print(a + b + c)
# Out:
# 2

# %%
x = 0
y = 1
a = x ^ y
print(a)
# Out:
# 1

# %%
number = int(input('Please provide a number: '))
print(number)
# Out:
# Please provide a number:  boom
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 number = int(input('Please provide a number: '))
#       2 print(number)
#
# ValueError: invalid literal for int() with base 10: 'boom'
