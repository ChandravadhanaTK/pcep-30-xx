# %%
emails = {
    'Chandra': 'tkchandravadhana@gmail.com',
    'Ezhil': 'ezhilpandian@gmail.com',
    'E C Akshayaa': 'ecakshayaa@gmail.com',
    'E C Yazhnilaa': 'ecyazhnilaa@gmail.com'    
}
print(emails['E C Akshayaa'])
# Out:
# ecakshayaa@gmail.com

# %%
emails = {
    'Chandra': 'tkchandravadhana@gmail.com',
    'Ezhil': 'ezhilpandian@gmail.com',
    'E C Akshayaa': 'ecakshayaa@gmail.com',
    'E C Yazhnilaa': 'ecyazhnilaa@gmail.com'    
}
print(emails['Chandra'])
# Out:
# tkchandravadhana@gmail.com

# %%
emails = {
    'Chandra': 'tkchandravadhana@gmail.com',
    'Ezhil': 'ezhilpandian@gmail.com',
    'E C Akshayaa': 'ecakshayaa@gmail.com',
    'E C Yazhnilaa': 'ecyazhnilaa@gmail.com',
    'E C Yazhnilaa': 'testrepeat@gmail.com'
}
print(emails)
# Out:
# {'Chandra': 'tkchandravadhana@gmail.com', 'Ezhil': 'ezhilpandian@gmail.com', 'E C Akshayaa': 'ecakshayaa@gmail.com', 'E C Yazhnilaa': 'testrepeat@gmail.com'}

# %%
emails = {
    'Chandra': 'tkchandravadhana@gmail.com',
    'Ezhil': 'ezhilpandian@gmail.com',
    'E C Akshayaa': 'ecakshayaa@gmail.com',
    'E C Yazhnilaa': 'ecyazhnilaa@gmail.com'
}
print(emails['tkchandravadhana@gmail.com'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 7
#       1 emails = {
#       2     'Chandra': 'tkchandravadhana@gmail.com',
#       3     'Ezhil': 'ezhilpandian@gmail.com',
#       4     'E C Akshayaa': 'ecakshayaa@gmail.com',
#       5     'E C Yazhnilaa': 'ecyazhnilaa@gmail.com'
#       6 }
# ----> 7 print(emails['tkchandravadhana@gmail.com'])
#
# KeyError: 'tkchandravadhana@gmail.com'

# %%
city_rankings = {
    'Bangkok': [7, 4, 7, 5],
    'Hanoi': [7, 6, 4, 5],
    'Manila': [6, 6, 4, 4, 5]
}
print(city_rankings)
# Out:
# {'Bangkok': [7, 4, 7, 5], 'Hanoi': [7, 6, 4, 5], 'Manila': [6, 6, 4, 4, 5]}
