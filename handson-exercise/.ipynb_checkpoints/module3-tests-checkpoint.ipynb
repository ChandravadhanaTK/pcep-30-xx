# %%
i = 0
while i <= 10:
    i += 1
    if i % 2 == 0:
        break
    print('*')
print('Finished')
# Out:
# *
# Finished

# %%
x = 1
x = x == x
print(x)
# Out:
# True

# %%
a = 5
b = 1
c = a > b or b < a and a == 1
print(c)
# Out:
# True

# %%
for a in range(1, 6):
    for b in range(1, 10):
         if (a == b):
           print(a)
# Out:
# 1
# 2
# 3
# 4
# 5
