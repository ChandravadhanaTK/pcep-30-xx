# %%
while True:
    name = input('Enter your name or EXIT to close the program: ')
    if(name == 'EXIT'):
        break
    print('Hello', name)
# Out:
# Enter your name or EXIT to close the program:  exit
# Hello exit
# Enter your name or EXIT to close the program:  TKC
# Hello TKC
# Enter your name or EXIT to close the program:  EXIT

# %%
for i in range(1,20):
    if i % 5 != 0:
        continue
    print(i)
# Out:
# 5
# 10
# 15
