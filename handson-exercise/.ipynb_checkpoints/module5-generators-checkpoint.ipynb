# %%
def get_number():
    for i in range(1, 4):
        yield i

print(get_number())
# Out:
# <generator object get_number at 0x0000016DD1BE8380>

# %%
generator = get_number()
print(next(generator))
print(next(generator))
print(next(generator))
print(next(generator))
# Out:
# 1
# 2
# 3
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[9], line 5
#       3 print(next(generator))
#       4 print(next(generator))
# ----> 5 print(next(generator))
#
# StopIteration:

# %%
for x in get_number():
    print(x)
# Out:
# 1
# 2
# 3

# %%
numbers = list(get_number())
print(numbers)
# Out:
# [1, 2, 3]
