# %%
top_cities = ['Chennai', 'Mumbai', 'Pune', 'Hyderabad', 'Agra']
print(top_cities)
# Out:
# ['Chennai', 'Mumbai', 'Pune', 'Hyderabad', 'Agra']

# %%
top_cities = ['Chennai', 'Mumbai', 'Pune', 'Hyderabad', 'Agra']
print(top_cities)
del top_cities[2]
print(top_cities)
# Out:
# ['Chennai', 'Mumbai', 'Pune', 'Hyderabad', 'Agra']
# ['Chennai', 'Mumbai', 'Hyderabad', 'Agra']

# %%
top_cities = ['Chennai', 'Mumbai', 'Pune', 'Hyderabad', 'Agra']
print(top_cities)
del top_cities[2:4]
print(top_cities)
# Out:
# ['Chennai', 'Mumbai', 'Pune', 'Hyderabad', 'Agra']
# ['Chennai', 'Mumbai', 'Agra']

# %%
top_cities = ['Chennai', 'Mumbai', 'Pune', 'Hyderabad', 'Agra']
print(top_cities)
del top_cities[:]
print(top_cities)
# Out:
# ['Chennai', 'Mumbai', 'Pune', 'Hyderabad', 'Agra']
# []

# %%
top_cities = ['Chennai', 'Mumbai', 'Pune', 'Hyderabad', 'Agra']
print(top_cities)
del top_cities
print(top_cities)
# Out:
# ['Chennai', 'Mumbai', 'Pune', 'Hyderabad', 'Agra']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       2 print(top_cities)
#       3 del top_cities
# ----> 4 print(top_cities)
#
# NameError: name 'top_cities' is not defined
