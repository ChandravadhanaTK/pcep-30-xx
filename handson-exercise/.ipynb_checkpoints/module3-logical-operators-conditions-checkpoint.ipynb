# %%
password = input('Do you know the secret password? ')
if password == '--secret':
    print('not correct')
else:
    print('correct secret')
# Out:
# Do you know the secret password?  tkc
# correct secret

# %%
condition = True

# %%
condition = true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 condition = true
#
# NameError: name 'true' is not defined

# %%
if True:
    print('condition met')
# Out:
# condition met

# %%
if False:
    print('condition not met')

# %%
if 1 == 2:
    print('true')

# %%
if 2 == 2.0:
    print('true')
# Out:
# true

# %%
if 2 == 2:
    print('true')
# Out:
# true
