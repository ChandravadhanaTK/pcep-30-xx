# %%
city_1 = 'Chennai'
city_2 = 'Mumbai'
city_3 = 'Pune'
city_4 = 'Hyderabad'

# %%
empty_list = []

# %%
top_cities = ['Chennai', 'Mumbai', 'Pune', 'Hyderabad']
print(top_cities)
# Out:
# ['Chennai', 'Mumbai', 'Pune', 'Hyderabad']

# %%
top_cities
# Out:
# ['Chennai', 'Mumbai', 'Pune', 'Hyderabad']

# %%
top_cities[2]
# Out:
# 'Pune'

# %%
top_cities[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 top_cities[4]
#
# IndexError: list index out of range

# %%
top_cities[-1]
# Out:
# 'Hyderabad'

# %%
top_cities[-2]
# Out:
# 'Pune'

# %%
top_cities[-5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 top_cities[-5]
#
# IndexError: list index out of range

# %%
top_cities[2:]
# Out:
# ['Pune', 'Hyderabad']

# %%
top_cities[:2]
# Out:
# ['Chennai', 'Mumbai']

# %%
top_cities[:]
# Out:
# ['Chennai', 'Mumbai', 'Pune', 'Hyderabad']

# %%
top_cities
# Out:
# ['Chennai', 'Mumbai', 'Pune', 'Hyderabad']

# %%
top_cities[10:15]
# Out:
# []
