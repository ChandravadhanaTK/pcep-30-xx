# %%
working_hours = float(input('How many hours did you work last month? '))
hourly_rate = float(input('What is your hourly rate? '))
salary = working_hours * hourly_rate
print(f'Last month, you earned {str(salary)} dollars')
# Out:
# How many hours did you work last month?  120
# What is your hourly rate?  200
# Last month, you earned 24000.0 dollars
