# %%
2+3
# Out:
# 5

# %%
5-4
# Out:
# 1

# %%
3*5
# Out:
# 15

# %%
15/3
# Out:
# 5.0

# %%
7/2
# Out:
# 3.5

# %%
15//3
# Out:
# 5

# %%
7//2
# Out:
# 3

# %%
7%2
# Out:
# 1

# %%
2**3
# Out:
# 8

# %%
2+3
# Out:
# 5

# %%
2+3.0
# Out:
# 5.0

# %%
2.0+3.0
# Out:
# 5.0
