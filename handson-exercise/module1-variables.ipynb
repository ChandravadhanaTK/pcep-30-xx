# %%
greeting = 'Hello, friend!'
print(greeting)
greeting='Hi, everybody!'
print(greeting)
# Out:
# Hello, friend!
# Hi, everybody!

# %%
print(new_greeting)
new_greeting='Hello'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(new_greeting)
#       2 new_greeting='Hello'
#
# NameError: name 'new_greeting' is not defined

# %%
from='Hello'
# Out:
#   Cell In[7], line 1
#     from='Hello'
#         ^
# SyntaxError: invalid syntax

# %%
global='Hello'
# Out:
#   Cell In[9], line 1
#     global='Hello'
#           ^
# SyntaxError: invalid syntax
