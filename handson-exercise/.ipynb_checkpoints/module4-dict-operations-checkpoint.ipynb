# %%
grades = {}

# %%
grades['Chandra'] = 'A+'

# %%
grades['Ezhil'] = 'B+'

# %%
print(grades)
# Out:
# {'Chandra': 'A+', 'Ezhil': 'B+'}

# %%
grades['Ezhil'] = 'A-'
print(grades)
# Out:
# {'Chandra': 'A+', 'Ezhil': 'A-'}

# %%
grades.update({'Ezhil': 'A+'})
print(grades)
# Out:
# {'Chandra': 'A+', 'Ezhil': 'A+'}

# %%
len(grades)
# Out:
# 2

# %%
if 'Chandra' in grades:
    print('Chandra got ', grades['Chandra'])
# Out:
# Chandra got  A+

# %%
del grades['Ezhil']
print(grades)
# Out:
# {'Chandra': 'A+'}

# %%
grades = {}
grades['Chandra'] = 'A+'
grades['Ezhil'] = 'B+'
for el in grades:
    print(el)
# Out:
# Chandra
# Ezhil

# %%
for el in grades.keys():
    print(el)
# Out:
# Chandra
# Ezhil

# %%
for el in grades.values():
    print(el)
# Out:
# A+
# B+

# %%
grades = {}
grades['Chandra'] = 'A+'
grades['Ezhil'] = 'B+'
for person, grades in grades.items():
    print(person, 'got', grades)
# Out:
# Chandra got A+
# Ezhil got B+
