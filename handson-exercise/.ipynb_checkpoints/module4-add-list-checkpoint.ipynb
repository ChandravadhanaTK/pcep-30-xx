# %%
book_ratings = [7, 9, 5, 6, 8]
print(book_ratings)
book_ratings.append(4)
print(book_ratings)
# Out:
# [7, 9, 5, 6, 8]
# [7, 9, 5, 6, 8, 4]

# %%
book_ratings = [7, 9, 5, 6, 8]
print(book_ratings)
book_ratings.insert(1,10)
print(book_ratings)
# Out:
# [7, 9, 5, 6, 8]
# [7, 10, 9, 5, 6, 8]
