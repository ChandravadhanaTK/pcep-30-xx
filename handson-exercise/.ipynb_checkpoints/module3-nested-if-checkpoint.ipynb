# %%
answer_a = input('Do you like travel? y/n: ')
if answer_a == 'y':
    print('Great to hear that you like to travel')
    answer_b = input('Do you like Asia? y/n: ')
    if answer_b == 'y':
        print('Congradulations! You can win a lottery ticket to Thailand')
    else:
        print('Sorry to hear that!')
else:
    print('Sorry to hear that!')
# Out:
# Do you like travel? y/n:  y
# Great to hear that you like to travel
# Do you like Asia? y/n:  n
# Sorry to hear that!
