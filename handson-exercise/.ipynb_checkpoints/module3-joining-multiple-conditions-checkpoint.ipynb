# %%
user_age = int(input('What is your age? '))
user_country = input('What is your country? ')

if user_age < 25 and user_country == 'India':
    print('You can apply for an Indian student exchange programme')
else:
    print('Sorry, you do not qualify')
# Out:
# What is your age?  30
# What is your country?  ind
# Sorry, you do not qualify

# %%
user_country = input('What is your country? ')

if user_country == 'Sweden' or user_country == 'India' or user_country == 'Germany':
    print('You can apply for the Swedenish student exchange programme')
else:
    print('Sorry, you do not qualify')
# Out:
# What is your country?  Dutch
# Sorry, you do not qualify

# %%
user_country = input('What is your country? ')

if not user_country == 'Germany':
    print('You are not from Germany')
else:
    print('You are from Germany')
# Out:
# What is your country?  Germany
# You are from Germany
